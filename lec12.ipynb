# %%
import Pkg; Pkg.add(["Plots"]);
import Logging; Logging.disable_logging(Logging.Info)
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/srv/rep/22-course-cse6643/mybinder/Project.toml`
#   No Changes to `~/srv/rep/22-course-cse6643/mybinder/Manifest.toml`
# LogLevel(1)

# %%
const STATIC_LECTURE = false;

# %%
using LinearAlgebra;
using Plots; plotlyjs(); default(l=5, size=(900,550), label=false);
using Printf;
using Polynomials;

BLAS.set_num_threads(1)

if STATIC_LECTURE
    default(fmt=:png)
end

prettyprint(a) = map(x -> @sprintf("%+.2f", x), v)

function imshow(x; kwargs...)
    return heatmap(x
        , aspect_ratio=:equal
        , framestyle=:none
        , yflip=true
        , c=:diverging_gwv_55_95_c39_n256
        ; kwargs...
    )
end
p = plot!([0,1],[0,1]);
# Out:
# WebIO._IJuliaInit()

# %% [markdown]
# ### Warmup

# %% [markdown]
# # Stability of Householder Triangularization & Back Substitution

# %% [markdown]
# ## Review

# %% [markdown]
# ### Backward Error Analysis
#
# Forward relative error ...
#
# $$
# \frac{\|\tilde{f}(x) - f(x)\|}{\|f(x)\|}
# \leq
# \frac{\|\tilde{f}(x) - f(\tilde x)\|}{\|f(x)\|}
# +
# \frac{\|f(\tilde{x}) - f(x)\|}{\|f(x)\|}
# $$

# %% [markdown]
# $$
# \leq
# \frac{\|\tilde{f}(x) - f(\tilde x)\|}{\|f(x)\|}
# +
# (\kappa(x) + o(1))\frac{\|\tilde{x} - x\|}{\|x\|}
# $$

# %% [markdown]
# $$
# \underbrace{\frac{\|\tilde{f}(x) - f(\tilde x)\|}{\|f(x)\|}}_{\substack{O(\epsilon_{\text{machine}}) \\ \text{if (backward) stable}}}
# +
# \underbrace{(\kappa(x) + o(1))}_{O(\kappa(x))}\underbrace{\frac{\|\tilde{x} - x\|}{\|x\|}}_{\substack{O(\epsilon_{\text{machine}}) \\ \text{if (backward) stable}}}
# = O(\kappa(x) \epsilon_{\text{machine}})
# $$

# %% [markdown]
# ... is bounded by the product of conditioning and backward relative error for stable algorithms

# %% [markdown]
# ### Review: forward and backward errors of Householder QR

# %%
n_samples = 100; m_min = 10; m_max = 50

conds = Float64[]; Q_errs = Float64[]
R_rel_errs = Float64[]; A_rel_errs = Float64[]
for i in 1:n_samples
    # random size, Q, and R
    m = rand(m_min:m_max)
    R = triu(randn(m, m)); Q = qr(randn(m, m)).Q
    # construct A
    A = Q * R
    # algorithm: Householder QR
    Q2, R2 = qr(A)
    # fix signs
    signs = diagm(sign.(diag(R)).*sign.(diag(R2)))
    Q2 = Q2 * signs; R2 = signs * R2
    # compute errors 
    Q_err = norm(Q2 - Q)
    R_rel_err = norm(R2 - R) / norm(R)
    A_rel_err = norm(A - Q2 * R2) / norm(A)
    push!(conds, cond(A))
    push!(Q_errs, Q_err)
    push!(R_rel_errs, R_rel_err)
    push!(A_rel_errs, A_rel_err)
end

# %%
q = plot(conds, Q_errs
    , st = :scatter
    , title = "||Q₂ - Q||"
)
r = plot(conds, R_rel_errs
    , st = :scatter
    , title = "||R₂ - R|| / ||R||"
)
a = plot(conds, A_rel_errs
    , st = :scatter
    , title = "||A - Q₂R₂|| / ||A||"
    , ylim = (1.e-17, 1.e0)
    , xlabel = "κ(A)"
)
plot(q, r, a, layout=(3,1)
    , scale = :log10

    , size = (600,600)
)
# Out:
#     <div id="90128103-ac9e-49b1-9d50-ac445261a12a" style="width:600px;height:600px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('90128103-ac9e-49b1-9d50-ac445261a12a', [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             5.987585220602913e13,
#             1.4281822673981278e6,
#             2.116914949221345e11,
#             1.2197994334754839e10,
#             3.3811978491869504e6,
#             2.5365477742212715e9,
#             9.284357444473145e10,
#             1.2367913503544776e8,
#             7.78819569606108e10,
#             5.872059825741256e7,
#             17984.35114199749,
#             4.991433444647679e16,
#             6.887402379201798e6,
#             1.4073421600214524e16,
#             3.631873856377191e9,
#             2.2589592821901584e11,
#             3.81965547945654e7,
#             2.1384015288719364e16,
#             1.6334779331549755e10,
#             3.716164698921397e10,
#             1.1831117750852441e7,
#             2.2413078179840436e11,
#             1.0826203139540136e10,
#             4.507879601250667e7,
#             2.3075114683440132e10,
#             1.868695752134782e17,
#             1.6221673631312845e15,
#             3.272188188737678e12,
#             3.2230358339116314e17,
#             27406.18624364312,
#             5.786699426120808e7,
#             6040.794111467171,
#             1.0395226134931239e15,
#             2.700114761591232e10,
#             9.984468045076453e10,
#             1.1160599350379544e17,
#             132871.58414610435,
#             6.259522741933787e12,
#             5.65175641106672e14,
#             32921.313296224,
#             5.3771088924405644e14,
#             1.3980515686460547e14,
#             6163.50043940513,
#             28803.48687656285,
#             14002.538613014813,
#             1.6845063317860484e7,
#             269596.81544455973,
#             5.3336307857881814e8,
#             1.712944242895445e10,
#             1.2050304795097288e12,
#             5927.004227529714,
#             18147.25674953011,
#             1.663616790021813e8,
#             8.935885848165823e9,
#             595395.6803743914,
#             2.6025731617995914e13,
#             4.1994649989450725e14,
#             1.6472165605264774e11,
#             3.382301990784444e12,
#             3.150835753350597e6,
#             1.417606883424689e18,
#             4.384988666792251e15,
#             4.683955453462552e8,
#             8.713673882942865e10,
#             5.7741583449445665e7,
#             1.5567551315202616e16,
#             1.2662414770338692e7,
#             1.3259494813429377e14,
#             1.305152795054771e7,
#             1.590320525491954e13,
#             962612.1504120651,
#             4.823782078980849e8,
#             1.7516849393084518e15,
#             1.3988096055664722e16,
#             1.326514996035507e13,
#             9.864720404625675e9,
#             7.256922735261569e17,
#             1.5975784929640327e10,
#             7.616433162355968e8,
#             1.115744991935397e12,
#             3.2771045265953403e9,
#             8.039470042214742e14,
#             701016.1095799989,
#             2.7044412037043316e14,
#             6.393261752278223e6,
#             6.854246000307075e8,
#             3.537851145502978e6,
#             29173.019917777234,
#             4.652852137040059e10,
#             9.225181729552032e10,
#             958767.3122802251,
#             9.802517817522957e12,
#             2.171758851006413e12,
#             24712.61384709525,
#             2.87730642990159e6,
#             7.418973859866728e13,
#             4.281106992255658e8,
#             6.491125636611799e7,
#             402020.5795053478,
#             1.1709086822216697e14
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.0008648493431875882,
#             3.576172585860355e-12,
#             4.510450177663816e-7,
#             1.935451299504347e-8,
#             3.556376900984959e-11,
#             5.000417917353005e-9,
#             3.174499130492041e-7,
#             1.5033040965694424e-9,
#             4.605415684733163e-7,
#             2.122335940569312e-10,
#             7.193852782555723e-14,
#             2.570646869916387,
#             4.970658443108825e-11,
#             0.08797885579630935,
#             7.526644519471384e-9,
#             1.3333889555241108e-6,
#             6.061410818706784e-10,
#             0.04644979678229371,
#             3.901311968850173e-8,
#             9.657008495827206e-8,
#             4.421611442573811e-11,
#             1.966597073567188e-6,
#             1.0039160164483239e-7,
#             4.925356651026688e-10,
#             3.002961164664675e-8,
#             1.3176579635347525,
#             0.006205041229126151,
#             1.6262604920938723e-6,
#             0.5846906331351264,
#             5.960257071419385e-13,
#             2.044017849209378e-11,
#             4.261006021699719e-14,
#             0.0031591973531006168,
#             4.231357056040299e-8,
#             8.396791953167882e-7,
#             2.242091255851059,
#             2.1376743335741816e-12,
#             1.2442978735216513e-5,
#             0.0006125234170511279,
#             5.271434837410965e-13,
#             0.00022300292072929495,
#             0.0003967706083262885,
#             8.698629335832425e-15,
#             1.5446698467761434e-13,
#             1.2444520758774805e-13,
#             9.133642211987762e-11,
#             1.2899326007874695e-12,
#             4.579422737706021e-9,
#             7.337337300957811e-9,
#             2.0192954056695796e-6,
#             1.2885299321799368e-13,
#             8.154468598686152e-13,
#             2.44421345526022e-10,
#             4.9810317227189e-8,
#             2.9375834550153597e-12,
#             0.0001303331765673058,
#             0.004001323888001445,
#             8.357626452642362e-7,
#             4.925644367225964e-6,
#             1.2392373494568217e-11,
#             2.8210589381212814,
#             0.046510433708026974,
#             6.863174664097079e-10,
#             3.622877674987956e-7,
#             4.5895845582021246e-11,
#             0.12018750708425308,
#             1.5337078445113652e-10,
#             0.00011939718300218804,
#             4.969846086716389e-11,
#             2.850490635698894e-5,
#             1.0535768561975157e-12,
#             9.846072672633362e-10,
#             0.005755078265441881,
#             0.029830281612476785,
#             3.450738613345888e-5,
#             8.856394088241381e-8,
#             0.0014781189990421709,
#             3.82733540237648e-9,
#             3.440418811689814e-10,
#             8.684701572753936e-7,
#             3.692710642051634e-8,
#             0.0001403318678193828,
#             1.199343177271796e-13,
#             0.0006192972326125564,
#             1.0880190265101048e-10,
#             3.0467595757978473e-9,
#             2.182943544995948e-12,
#             3.639362086481136e-13,
#             1.4893129940248176e-7,
#             8.55704020657561e-8,
#             1.0676480758907367e-12,
#             2.673459273289638e-5,
#             1.473759191918795e-6,
#             2.9171383646211034e-13,
#             3.5145950307599526e-12,
#             5.681098329348749e-5,
#             4.950830788740791e-11,
#             3.903750718383188e-10,
#             1.4272556026643316e-12,
#             6.458923890675727e-5
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             5.987585220602913e13,
#             1.4281822673981278e6,
#             2.116914949221345e11,
#             1.2197994334754839e10,
#             3.

# %% [markdown]
# - Small backward errors (stable), forward errors $\propto \kappa(A)$

# %% [markdown]
# ### T&B Theorem 16.1
#
# Let the QR factorization $A = QR$ of a matrix $A \in \mathbb{C}^{m \times n}$ be computed by Householder triangularization on a computer satisfying the floating point axioms, and let the computed $\tilde{Q}$ be
#
# $$
# \tilde{Q} = \tilde{Q}_1 \tilde{Q}_2 \dots \tilde{Q}_n,
# $$
#
# where $\tilde{Q}_k$ is the Householder reflector of the computed reflector $\tilde{v}_k$.  Then
#
# $$\tilde{Q}\tilde{R} = A + \delta A, \quad \frac{\|\delta A\|}{\|A\|} = O(\epsilon_{\text{machine}}), \quad \text{[backward stability]}$$
#
# for some $\delta A \in \mathbb{C}^{m \times n}$.

# %% [markdown]
# ### Details on $\tilde{Q}_k$
#
# - In Householder QR the solution is not a computed $Q$, it is the Householder reflectors $v_k$ that define
# $Q_k$:
#
# $$Q = Q_1 Q_2 \cdots Q_n.$$

# %% [markdown]
# - $\tilde{Q}_k$ is the _exactly unitary_ matrix for the computed vector $\tilde{v}_k$
# - so $\tilde{Q}$ is _exactly unitary_, even though $\tilde{Q} \neq Q$ (as demonstrated in the experiment)

# %% [markdown]
# ## Analyzing Solving $Ax = b$ with Householder QR
#
# > QR factorization is generally not an end itself, but a means to other ends such as solution of a system of equations [...]

# %% [markdown]
# > Is its backward stability enough to make it a satisfactory piece of a larger algorithm? [...] or do we need accuracy of $Q$ and $R$ individually?

# %% [markdown]
# ### Solving $Ax = b$ with Householder QR

# %%
function householder_solve(A, b)
    Q, R = qr(A) # Factor A by Householder triangularization
    y = Q' * b   # Compute Q* b by applying the reflectors in order
    x = R \ y    # Solve the triangular system R x = y by back substitution
    return x
end;

# %% [markdown]
# **Backward stability of steps (takes as given for now):**

# %% [markdown]
# 1. $\tilde{Q}, \tilde{R} \gets QR(A)$: just stated as T&B Theorem 16.1

# %% [markdown]
# 2. $\tilde y \gets \tilde{Q}^* b$: yes (**HW 3 Q 6**, roughly)
#
# $$(\tilde{Q} + \delta Q) \tilde y = b, \quad \|\delta Q\| = O(\epsilon_{\text{machine}})$$

# %% [markdown]
# 3. $\tilde x \gets \tilde{R}^{-1} \tilde y$: yes (coming up next),
#
# $$(\tilde R + \delta R) \tilde x = \tilde y, \quad \frac{\|\delta R\|}{\|\tilde R\|} = O(\epsilon_{\text{machine}}).$$

# %% [markdown]
# ### T&B Theorem 16.2.
#
# `householder_solve` is backwardstable, satisfying
#
# $$
# (A + \Delta A) \tilde x = b, \quad \frac{\|\Delta A\|}{\|A\|} = O(\epsilon_{\text{machine}})
# $$
#
# for some $\Delta A \in \mathbb{C}^{m \times m}$.

# %% [markdown]
# $$
# \begin{aligned}
# A + \delta A &= \tilde Q \tilde R &\star\\
# (\tilde Q + \delta Q) \tilde y &= b &\clubsuit \\
# (\tilde R + \delta R) \tilde x &= \tilde y & \spadesuit
# \end{aligned}
# $$

# %% [markdown]
# _Proof._

# %% [markdown]
# Combine $\clubsuit$, $\spadesuit$:
#
# $$
# b = (\tilde Q + \delta Q)(\tilde R + \delta R) \tilde x = [\tilde Q \tilde R + (\delta Q) \tilde R + \tilde Q (\delta R) + (\delta Q)(\delta R)]\tilde x
# $$

# %% [markdown]
# Apply $\star$:
#
# $$
# b = [A + \underbrace{\delta A + (\delta Q) \tilde R + \tilde Q (\delta R) + (\delta Q)(\delta R)}_{\Delta A}]\tilde x
# $$

# %% [markdown]
# We want $\|\Delta A\| / \|A\| = O(\epsilon_{\text{machine}})$, will show each of the four terms is $O(\epsilon_{\text{machine}})$

# %% [markdown]
# $$\frac{\|\delta A\|}{\|A\|} = O(\epsilon_{\text{machine}})\quad[\star]$$

# %% [markdown]
# $$
# \frac{\|(\delta Q) \tilde R\|}{\|A\|} \leq
# \|\delta Q\| \frac{\|\tilde R\|}{\|A\|} =
# \|\delta Q\| \frac{\|\tilde{Q}^*(A + \delta A)\|}{\|A\|}
# =
# \underbrace{\|\delta Q\|}_{O(\epsilon_{\text{machine}}) [\clubsuit]} \underbrace{\frac{\|A + \delta A\|}{\|A\|}}_{O(1)}
# = O(\epsilon_{\text{machine}})
# $$

# %% [markdown]
# $$
# \frac{\|\tilde{Q}(\delta R)\|}{\|A\|} =
# \frac{\|\delta R\|}{\|A\|} = \underbrace{\frac{\|\delta R\|}{\|\tilde R\|}}_{O(\epsilon_{\text{machine}}) [\spadesuit]}\frac{\|\tilde R\|}{\|A\|} =O(\epsilon_{\text{machine}})
# $$

# %% [markdown]
# $$\frac{\|(\delta Q)(\delta R)\|}{\|A\|} \leq
# \|(\delta Q)\|\frac{\|(\delta R)\|}{\|A\|} = O(\epsilon_{\text{machine}}^2)
# $$

# %% [markdown]
# ### Now applying our backward error analysis theorem

# %% [markdown]
# **T&B Theorem 16.3.** The computed solution $\tilde{x}$ of `householder_solve` satisfies
#
# $$\frac{\|\tilde x - x\|}{\|x\|} = O(\kappa(A) \epsilon_{\text{machine}}).$$

# %% [markdown]
# ## Stability of Back Substitution

# %% [markdown]
# ### Triangular Systems
#
# We wish to solve $Rx = b$,
#
# $$
# \begin{bmatrix}
# r_{11} & r_{12} & \cdots & r_{1m} \\
#        & r_{22} &        & \vdots \\
#        &        & \ddots & \vdots \\
#        &        &        & r_{mm}
# \end{bmatrix}
# \begin{bmatrix}
# x_1 \\ x_2 \\ \vdots \\ x_m
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1 \\ b_2 \\ \vdots \\ b_m
# \end{bmatrix}
# $$

# %% [markdown]
# Subproblem of:
#
# - Solving $Ax = b$ / least squares by QR
# - Solving $Ax = b$ by LU (Gaussian elimination)
# - Solving $Ax = b$ by Cholesky

# %%
function backsubstitution(R, b)
    m = length(b)
    x = copy(b)
    for j = m:-1:1
        x[j] /= R[j,j]
        for i = 1:j-1
            x[i] -= R[i,j] * x[j]
        end
    end
    return x
end;

# %%
function backsubstitution_vec(R, b)
    m = length(b)
    x = copy(b)
    for j = m:-1:1
        x[j] /= R[j,j]
        x[1:j-1] -= R[1:j-1,j] * x[j]
    end
    return x
end;

# %% [markdown]
# These two algorithms are floating-point identical.  They differ from backslash only in the order of subtractions:

# %%
m = 100;
R = qr(randn(m,m)).R

b = randn(m)
x_backslash = R \ b
x_backsub = backsubstitution(R, b)
x_backsubv = backsubstitution_vec(R, b)
display(norm(x_backslash - x_backsub) / norm(x_backslash))
display(norm(x_backslash - x_backsubv) / norm(x_backslash))
# Out:
# 4.131335805589927e-16
# 4.131335805589927e-16

# %% [markdown]
# ### T&B Theorem 17.1.
#
# Suppose $b = \mathrm{fl}(b)$ and $R = \mathrm{fl}(R)$.  `backsubstitution` is backward stable:
#
# $$(R + \delta R) \tilde x = b$$
#
# for some upper-triangular $\delta R$ with
#
# $$\frac{\|\delta R\|}{\|R\|} = O( \epsilon_{\text{machine}} ).$$
#
# Elementwise,
#
# $$
# \frac{|\delta r_{ij}|}{|r_{ij}|} \leq m \epsilon_{\text{machine}} + O(\epsilon^2).
# $$

# %% [markdown]
# ### Exercise
#
# What does this theorem imply about $\|\tilde x - x\| / \|x\|$?

# %%
n_samples = 100; m_min = 10; m_max = 50

conds = Float64[]; 
x_rel_errs = Float64[]; b_rel_errs = Float64[]
for i in 1:n_samples
    # random size, R, and x
    m = rand(m_min:m_max)
    # construct b
    # algorithm: backsubstitution
    # compute errors 
    push!(conds, cond(R))
end

# %%
x = plot(conds, x_rel_errs
    , st = :scatter
    , title = "||x₂ - x|| / ||x||"
)
b = plot(conds, b_rel_errs
    , st = :scatter
    , title = "||b - R x₂|| / ||R||"
    , ylim = (1.e-17, 1.e0)
    , xlabel = "κ(A)"
)
plot(x, b, layout=(2,1)
    , scale = :log10

    , size = (600,600)
)
# Out:
#     <div id="0c670918-4a67-46cd-a2db-193a55536fa3" style="width:600px;height:600px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('0c670918-4a67-46cd-a2db-193a55536fa3', [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             4.379580452585969e15,
#             3657.889161936402,
#             1.3633243983465812e14,
#             2.526296432386738e11,
#             4.9624486758784974e8,
#             2.3468934404514476e16,
#             1.0024919535293026e7,
#             577797.1047178992,
#             2.775985426388117e10,
#             2.208473995974944e16,
#             1.910114479783313e11,
#             583.4469804958931,
#             5.158063716788035e7,
#             9.043728812745185e18,
#             3.1280736124220776e11,
#             3.0349382185165573e7,
#             6.669569663042176e17,
#             2.5554105620429244e16,
#             2.4529851974123505e10,
#             7.893111200322525e10,
#             666924.982347098,
#             4.809917863176898e9,
#             1.0027460698254192e9,
#             9.133946397687915e16,
#             24706.201976142445,
#             3.358255909455145e12,
#             131778.82496028452,
#             4.192579052121002e14,
#             1.0676974466176298e6,
#             1.0901575223601496e10,
#             9.841704973682806e6,
#             4.231769384994135e6,
#             8.995617259875314e7,
#             7.531906691312072e12,
#             7644.101218857554,
#             1.4827398638837805e17,
#             7.20782868525969e14,
#             4.7978200024399675e7,
#             1.2868781148500775e11,
#             1.6300036620757421e10,
#             7.683290994378116e11,
#             1885.9663738556226,
#             4.5793453144317e14,
#             298.1377609937286,
#             9.360510772346185e10,
#             6.257155531596018e7,
#             2.149986428937424e10,
#             6.308874750180935e10,
#             8.027536406291042e13,
#             1.0241811862939099e7,
#             7.382727233920301e9,
#             1.2830223048009702e16,
#             2.784948766453511e9,
#             6.820609849997173e11,
#             1.1025457204675835e10,
#             1.4029450812765744e11,
#             1.6323454249120194e6,
#             4.249772374639047e7,
#             1.2410370295265038e10,
#             6.128746424982782e9,
#             3.796118628904318e8,
#             2.691580670276382e8,
#             1.7532996531407156e9,
#             3.8024806024636054e9,
#             3.2132442627829994e14,
#             9.538191105297323e11,
#             3.087418542095918e8,
#             405333.7264644214,
#             3.1701570049561462e6,
#             3.8562873084547585e6,
#             1.4184366365215342e9,
#             2.415864484798833e17,
#             1.0026768604993389e17,
#             7.548083459426308e15,
#             1.095520460818698e18,
#             3.956256688664157e16,
#             1.1851252580652971e11,
#             9.749979026618327e10,
#             1.038075368054369e13,
#             3.6806264093090155e15,
#             7.46677949233363e12,
#             1.7633486876936847e8,
#             6.248827396179138e11,
#             3.2981552944321786e6,
#             3.359763990369649e11,
#             5.042613579545327e12,
#             9.37030149410631e12,
#             8.340758836801852e15,
#             3.930787538127247e12,
#             1.4278801004893823e12,
#             6.676105876213615e11,
#             2.1830048052422586e13,
#             310315.5676405681,
#             47053.64125795018,
#             1.9618493509644458e17,
#             5.801665310396159e9,
#             2.335934782892078e16,
#             9.475602289218388e6,
#             1.262749276950568e8,
#             1.5541127973313303e13
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             0.00041887299847620665,
#             3.5122305359024e-14,
#             2.6422603170784192e-5,
#             8.126457823372677e-7,
#             2.0880971847876002e-10,
#             0.001011907219741743,
#             2.0105714783507538e-11,
#             1.733188083157564e-12,
#             4.2055618593961024e-9,
#             0.03820090771924396,
#             3.5901667762959373e-9,
#             2.1498047764714594e-16,
#             4.0921572546218755e-11,
#             3.4156931677985085,
#             4.0862094499364466e-7,
#             1.9337828204888765e-10,
#             1.2198826150235123,
#             0.059507885890831315,
#             1.147358658711758e-9,
#             1.123141506670084e-8,
#             5.210060876424305e-12,
#             6.589604862040016e-9,
#             3.311403553621176e-9,
#             0.001927365592727233,
#             9.351088055488306e-14,
#             1.6003824028654683e-6,
#             2.664312154089926e-12,
#             7.51458671231317e-5,
#             3.653148700168483e-12,
#             3.6520960794946974e-9,
#             2.2028566348421725e-11,
#             1.3159253408738425e-12,
#             2.8913286161837668e-11,
#             3.7201357546634577e-6,
#             4.4468308897877785e-14,
#             0.4027782091387373,
#             0.0005588314122796875,
#             5.471083709398547e-10,
#             8.85203287552228e-8,
#             3.6376405067210557e-8,
#             5.1141221127002197e-8,
#             1.6333516630473037e-14,
#             0.00021518749408267355,
#             3.7427033377831725e-16,
#             1.11176812583103e-7,
#             5.459878208844798e-10,
#             2.226423486643336e-9,
#             2.2326955025127978e-7,
#             1.8723372691852098e-5,
#             1.127061038119254e-11,
#             1.4156907042513615e-9,
#             0.0018785000373014462,
#             3.737191304996343e-10,
#             1.165285471904994e-7,
#             7.874592311289654e-8,
#             2.329358316163521e-8,
#             5.092846785801517e-12,
#             1.1441574333286222e-10,
#             1.7458381294988305e-9,
#             1.1948529241874228e-9,
#             3.1331050178213906e-11,
#             1.0673546870932224e-9,
#             1.5649403946060449e-9,
#             8.186824886622057e-10,
#             3.7695191402578016e-5,
#             3.494063588077898e-7,
#             1.140852710133144e-9,
#             2.731806960003568e-13,
#             7.180163788489131e-12,
#             3.3537819362509886e-12,
#             1.6568950434211748e-10,
#             0.3482722117560224,
#             0.013447078011550793,
#             0.0026076704432654806,
#             0.019755714924220326,
#             0.024304055966879092,
#             2.0968277555129308e-7,
#             3.3246042868326057e-9,
#             2.5090932750712707e-6,
#             3.853520728484001e-5,
#             2.9162713087036824e-6,
#             3.1698259353699285e-10,
#             6.605957390811611e-7,
#             2.9060635349632304e-12,
#             3.7555018550442605e-7,
#             7.73746648176105e-6,
#             8.76281146714559e-7,
#             0.015069141212797977,
#             1.401111751862138e-7,
#             2.6868764952751557e-6,
#             5.232180295818069e-7,
#             1.4920772655301798e-5,
#             8.363991016844664e-13,
#             3.7565846882998864e-13,
#             0.26244133853361074,
#             6.7309719584703495e-9,
#             0.0007801034400947124,
#             2.7228848064969455e-13,
#             4.280631993296638e-11,
#             0.00011284251571770057
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             4.379580452585969e15,
#             3657.889161936402,
#             1.3633243983465812e14,
#             2.52

# %% [markdown]
# Remember we are trying to prove $(R + \delta R)\tilde x = b$: accumulate backward errors into $\tilde{R}$

# %% [markdown]
# ### A useful lemma (Higham)
#
# If $|\epsilon_i| \leq \epsilon_{\text{machine}}$ for each $i$ and $\rho_i = \pm 1$, then
#
# $$
# \prod_{i=1}^n (1 + \epsilon_i)^{\rho_i} = (1 + \theta_n), \quad |\theta_n| \leq \frac{n\epsilon_{\text{machine}}}{1 - n\epsilon_{\text{machine}}} =: \gamma_n = n \epsilon_{\text{machine}} + O(\epsilon_{\text{machine}}^2).
# $$
#
# We can treat $(1 + \epsilon_i)^{-1}$ and $(1 + \epsilon)$ the same!

# %% [markdown]
# If $\theta_n$ appears twice in the same expression, such as $x(1 + \theta_n) + y(1 + \theta_n)$, each one represents a different accumulated error.

# %% [markdown]
# ## $m = 1$

# %% [markdown]
# $$\tilde{x}_1 \gets b_1 \bigcirc\!\!\!\!\!\!\div\ \ r_{11}$$

# %% [markdown]
# By floating point axiom,
#
# $$\tilde x_1 = (b_1 / r_{11})(1 + \epsilon_1) = b_1 / (r_{11}(1 + \epsilon_1)^{-1})$$

# %% [markdown]
# By our useful lemma,
#
# $$\tilde{x}_1 = b_1 / (r_{11}(1 + \theta_1)) \Rightarrow (r_{11} + \theta_1 r_{11}) \tilde{x}_1 = b_1.$$

# %% [markdown]
# $$\frac{|\theta_1 r_{11}|}{|r_{11}|} = |\theta_1| \leq \gamma_1 = \epsilon_{\text{machine}} + O(\epsilon_{\text{machine}}^2).$$

# %% [markdown]
# ### $m = 2$
#
# The prevous case is now used in row 2,
#
# $$
# \tilde{x}_2 = b_2 / (r_{22}(1 + \theta_1))
# $$

# %% [markdown]
# The next step:
#
# $$\tilde{x}_1 = (b_{1} \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_2 \otimes r_{12})) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}$$

# %% [markdown]
# $$\tilde{x}_2 \otimes r_{12} = \tilde{x}_2 r_{12} (1 + \epsilon_2)$$

# %% [markdown]
# $$b_1 \bigcirc\!\!\!\!\!\!\!-\ \ \tilde{x}_2 r_{12}(1 + \epsilon_2) =
# (b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))(1 + \epsilon_3)$$

# %% [markdown]
# $$b_1 \bigcirc\!\!\!\!\!\!\!-\ \ \tilde{x}_2 r_{12}(1 + \epsilon_2) =
# (b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))(1 + \epsilon_3)$$

# %% [markdown]
# $$
# \begin{aligned}
# (b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))(1 + \epsilon_3) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}
# &= \frac{(b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))}{r_{11}}(1 + \epsilon_3)(1 + \epsilon_4)\\ &=
# \frac{(b_1 - \tilde{x}_2 r_{12}(1 + \epsilon_2))}{r_{11}(1 + \theta_2)}
# \end{aligned}$$

# %% [markdown]
# $$
# \begin{aligned}
# \Rightarrow r_{11}(1 + \theta_2)\tilde{x}_1 + r_{12}(1 + \epsilon_2)\tilde x_2 &= b_1 \\
# r_{22}(1 + \theta_1) \tilde{x}_2 &= b_2.
# \end{aligned}
# $$

# %% [markdown]
# $$
# [R \odot (I + \Theta_2)] \tilde x = b,
# $$
#
# - $\odot$ Hadamard (pointwise) product of matrices
# - $\Theta_k$ upper triangular $k \times k$ matrix whose entries are $\theta_k$

# %% [markdown]
# ### $m = 3, \dots$
#
# $$\tilde{x}_1 = (\cdots ((b_{1} \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_m \otimes r_{1m})) \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_{m-1} \otimes r_{1{m-1}})) \bigcirc\!\!\!\!\!\!\!-\ \ \cdots \bigcirc\!\!\!\!\!\!\!-\ \ (\tilde{x}_2 \otimes r_{12})) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}$$
#
# (our `backsubstitution` does the updates in the opposite order of the book)

# %% [markdown]
# What we had in the top row of the $m=2$ case can generalize like
#
# $$
# \begin{aligned}
# \tilde{x}_1 &= \left([b_1 - \{r_{1,3:m} \odot (1 + \vec{\theta}_{m-2})\} \cdot\tilde{x}_{3:m}] (1 + \theta_{m-2}) \bigcirc\!\!\!\!\!\!\!-\ \ (r_2 (1 + \epsilon_1)) \cdot \tilde x_2\right) \bigcirc\!\!\!\!\!\!\div\ \ r_{11}
# \\
# &= \frac{\left([b_1 - \{r_{1,3:m} \odot (1 + \vec{\theta}_{m-2})\} \cdot\tilde{x}_{3:m}] (1 + \theta_{m-2}) - (r_2 (1 + \epsilon_2)) \cdot \tilde x_2\right)}{r_{11}(1 + \theta_2)}
# \end{aligned}
# $$
#
# where $\vec{\theta}_{m-2}$ is a vector with $\theta_{m-2}$ entries

# %% [markdown]
# we want to sneak that $(1 + \epsilon_1)$ term out so that it doesn't perturb $b_1$

# %% [markdown]
# Divide the top and the bottom by $(1 + \theta_{m-2})$, combining $(1 + \theta_{m-2})^{-1}(1 + \epsilon_2)$
# into $(1 + \theta_{m-1})$:
#
# $$
# \begin{aligned}
# \tilde{x}_1
# &= \frac{\left([b_1 - \{r_{1,3:m} \odot (1 + \vec{\theta}_{m-2})\} \cdot\tilde{x}_{3:m}] - (r_2 (1 + \theta_{m-1})) \cdot \tilde x_2\right)}{r_{11}(1 + \theta_m)}
# \\
# &= \frac{\left(b_1 - \{r_{1,3:m} \odot (1 + \vec{\theta}_{m-2})\} \cdot\tilde{x}_{3:m} - (r_2 (1 + \theta_{m-1})) \cdot \tilde x_2\right)}{r_{11}(1 + \theta_m)}
# \\
# &= \frac{\left(b_1 - \{r_{1,2:m} \odot (1 + \vec{\theta}_{m-1})\} \cdot\tilde{x}_{2:m}\right)}{r_{11}(1 + \theta_m)}
# \end{aligned}
# $$

# %% [markdown]
# This matches the inductive case and gives us the backward error form
#
# $$
# [R \odot (I + \Theta_m)] \tilde x = b,
# $$
